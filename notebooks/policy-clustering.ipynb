# %% [markdown]
# # Goal
#
# Our predictions are pretty good, but some state predictions are not very accurate.
#
# We've tried to ameliorate this by clustering "connected" states via the number of people travelling between states. This didn't work out very well.
#
# We've looked around for more data, and have found a database of government policy responses. Can we use this to cluster states?

# %%
import numpy as np
import pandas as pd

# %%
# Set low_memory so pandas stops complaining about mixed dtypes. 
# This is probably a bad decision. 
df = pd.read_csv('../data/policy-combined.csv', low_memory=False)
df.head()
df.describe()
# Out:
#                Date  C1_School closing       C1_Flag  C2_Workplace closing  \
# count  8.851000e+04       84623.000000  62019.000000          84185.000000
# mean   2.020061e+07           1.826525      0.801142              1.336354
# std    3.151221e+02           1.266415      0.399144              1.063181
# min    2.020010e+07           0.000000      0.000000              0.000000
# 25%    2.020032e+07           0.000000      1.000000              0.000000
# 50%    2.020062e+07           2.000000      1.000000              2.000000
# 75%    2.020091e+07           3.000000      1.000000              2.000000
# max    2.020113e+07           3.000000      1.000000              3.000000
#
#             C2_Flag  C3_Cancel public events       C3_Flag  \
# count  57447.000000             84207.000000  61224.000000
# mean       0.767316                 1.286247      0.872044
# std        0.422546                 0.866134      0.334044
# min        0.000000                 0.000000      0.000000
# 25%        1.000000                 0.000000      1.000000
# 50%        1.000000                 2.000000      1.000000
# 75%        1.000000                 2.000000      1.000000
# max        1.000000                 2.000000      1.000000
#
#        C4_Restrictions on gatherings       C4_Flag  C5_Close public transport  \
# count                   84189.000000  57507.000000               84194.000000
# mean                        2.261744      0.811206                   0.562368
# std                         1.674902      0.391349                   0.719219
# min                         0.000000      0.000000                   0.000000
# 25%                         0.000000      1.000000                   0.000000
# 50%                         3.000000      1.000000                   0.000000
# 75%                         4.000000      1.000000                   1.000000
# max                         4.000000      1.000000                   2.000000
#
#        ...  StringencyIndex  StringencyIndexForDisplay  StringencyLegacyIndex  \
# count  ...     83843.000000                84639.00000           83843.000000
# mean   ...        50.692412                   50.71804              56.776758
# std    ...        29.479242                   29.39300              30.681218
# min    ...         0.000000                    0.00000               0.000000
# 25%    ...        25.930000                   25.93000              34.520000
# 50%    ...        57.410000                   57.41000              66.670000
# 75%    ...        75.000000                   75.00000              80.950000
# max    ...       100.000000                  100.00000             100.000000
#
#        StringencyLegacyIndexForDisplay  GovernmentResponseIndex  \
# count                     84639.000000             76083.000000
# mean                         56.811443                48.413032
# std                          30.582344                26.167773
# min                           0.000000                 0.000000
# 25%                          35.710000                30.360000
# 50%                          66.670000                57.440000
# 75%                          80.950000                68.150000
# max                         100.000000                95.540000
#
#        GovernmentResponseIndexForDisplay  ContainmentHealthIndex  \
# count                       76885.000000            83794.000000
# mean                           48.493649               50.747201
# std                            26.091436               27.346344
# min                             0.000000                0.000000
# 25%                            30.950000               31.600000
# 50%                            57.440000               59.720000
# 75%                            68.150000               72.220000
# max                            95.540000               98.960000
#
#        ContainmentHealthIndexForDisplay  EconomicSupportIndex  \
# count                      84595.000000          76077.000000
# mean                          50.815922             40.027045
# std                           27.265819             33.726705
# min                            0.000000              0.000000
# 25%                           31.940000              0.000000
# 50%                           59.720000             37.500000
# 75%                           72.220000             62.500000
# max                           98.960000            100.000000
#
#        EconomicSupportIndexForDisplay
# count                    76880.000000
# mean                        40.079832
# std                         33.706564
# min                          0.000000
# 25%                          0.000000
# 50%                         37.500000
# 75%                         62.500000
# max                        100.000000
#
# [8 rows x 42 columns]

# %%
df = pd.DataFrame(df.loc[df['CountryCode'] == 'USA'])
df = pd.DataFrame(df.loc[df['Jurisdiction'] == 'STATE_TOTAL'])

# %%
states = np.unique(df['RegionName'])

scores = dict()
for state in states: 
    state_data = df.loc[df['RegionName'] == state]
    scores[state] = state_data['GovernmentResponseIndex'].median()

# %%
print(scores)
# Out:
# {'Alabama': 54.17, 'Alaska': 61.31, 'Arizona': 62.2, 'Arkansas': 57.14, 'California': 71.73, 'Colorado': 63.69, 'Connecticut': 72.02, 'Delaware': 67.26, 'Florida': 59.52, 'Georgia': 60.71, 'Hawaii': 69.05, 'Idaho': 51.79, 'Illinois': 56.55, 'Indiana': 59.52, 'Iowa': 58.33, 'Kansas': 55.65, 'Kentucky': 69.05, 'Louisiana': 61.31, 'Maine': 70.83, 'Maryland': 65.18, 'Massachusetts': 64.88, 'Michigan': 56.85, 'Minnesota': 56.55, 'Mississippi': 58.93, 'Missouri': 48.21, 'Montana': 59.23, 'Nebraska': 58.33, 'Nevada': 60.71, 'New Hampshire': 51.19, 'New Jersey': 64.29, 'New Mexico': 72.02, 'New York': 77.08, 'North Carolina': 64.88, 'North Dakota': 48.51, 'Ohio': 61.9, 'Oklahoma': 46.43, 'Oregon': 60.71, 'Pennsylvania': 63.99, 'Rhode Island': 71.43, 'South Carolina': 56.85, 'South Dakota': 44.35, 'Tennessee': 56.25, 'Texas': 54.17, 'Utah': 55.95, 'Vermont': 70.24, 'Virgin Islands': 57.14, 'Virginia': 56.85, 'Washington': 62.8, 'Washington DC': 65.48, 'West Virginia': 58.93, 'Wisconsin': 59.52, 'Wyoming': 60.12}
